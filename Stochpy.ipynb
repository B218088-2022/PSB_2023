# %%
import stochpy
smod = stochpy.SSA()
smod.DoStochSim(IsTrackPropensities=True)
smod.PlotSpeciesTimeSeries()
smod.PlotPropensitiesTimeSeries()

# %%
smod.DoStochSim(end=10**5)
smod.GetSpeciesAutocorrelations()
smod.PlotSpeciesAutocorrelations(nlags=25)
smod.GetWaitingtimes()
smod.PlotWaitingtimesDistributions()
stochpy.plt.xlim([10**-4,10**0])
# Out:
# simulating .
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 2
#       1 smod.DoStochSim(end=10**5)
# ----> 2 smod.GetSpeciesAutocorrelations()
#       3 smod.PlotSpeciesAutocorrelations(nlags=25)
#       4 smod.GetWaitingtimes()
#
# File ~/miniconda3/envs/sys_bio/lib/python3.10/site-packages/stochpy/modules/StochSim.py:1238, in SSA.GetSpeciesAutocorrelations(self, species2calc, n_samples)
#    1236     for s_id in species2calc:
#    1237         s_index = self.sim_species_tracked.index(s_id)
# -> 1238         L_species_autocorrelations[s_index].append(Analysis.Autocorrelation(self.data_stochsim_grid.species[s_index][n]))
#    1240 self.data_stochsim_grid.setSpeciesAutocorrelations(L_species_autocorrelations)
#    1242 (self.data_stochsim_grid.species_autocorrelations_means,
#    1243 self.data_stochsim_grid.species_autocorrelations_standard_deviations) = Analysis.GetAverageResults(L_species_autocorrelations)
#
# File ~/miniconda3/envs/sys_bio/lib/python3.10/site-packages/stochpy/modules/Analysis.py:395, in Autocorrelation(s, **kwargs)
#     393     s = RemoveBias(s, axis)
#     394     kwargs['debias'] = False
# --> 395 sxx = AutoCov(s, **kwargs)
#     396 all_lags = kwargs.get('all_lags', False)
#     397 if all_lags:
#
# File ~/miniconda3/envs/sys_bio/lib/python3.10/site-packages/stochpy/modules/Analysis.py:296, in AutoCov(s, **kwargs)
#     294     s = RemoveBias(s, axis)
#     295 kwargs['debias'] = False
# --> 296 return CrossCov(s, s, **kwargs)
#
# File ~/miniconda3/envs/sys_bio/lib/python3.10/site-packages/stochpy/modules/Analysis.py:371, in CrossCov(x, y, axis, all_lags, debias)
#     369 slicing = [slice(d) for d in x.shape]
#     370 slicing[axis] = slice(None,None,-1)
# --> 371 sxy = FFTconvolve(x, y[tuple(slicing)], axis=axis, mode='full')
#     372 N = x.shape[axis]
#     373 sxy /= N
#
# File ~/miniconda3/envs/sys_bio/lib/python3.10/site-packages/stochpy/modules/Analysis.py:325, in FFTconvolve(in1, in2, mode, axis)
#     323     ret = np.fft.fftpack.ifftn(IN1)[fslice].copy()
#     324 else:
# --> 325     IN1 = np.fft.fftpack.fft(in1,fsize,axis=axis)
#     326     IN1 *= np.fft.fftpack.fft(in2,fsize,axis=axis)
#     327     ret = np.fft.fftpack.ifft(IN1,axis=axis)[fslice].copy()
#
# AttributeError: module 'numpy.fft' has no attribute 'fftpack'
